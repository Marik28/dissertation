# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# patching
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

# %%
data_dir = Path(".").resolve().parent.parent / "data"

# %%
data_dir
# Out:
# PosixPath('/home/mfitsek@wooppay.kz/PycharmProjects/dissertation/data')

# %%
df = pd.read_excel(data_dir / "modbus" / "RS-485.xlsx")

# %%
df.head()
# Out:
#                                    Параметр Имя ОВЕН           Назначение  \
# 0  Группа LvoP. Оперативные параметры (только чте...                  NaN
# 1                                               STAT      Регистр статуса
# 2                                                 PV  Измеренная величина
# 3  Группа LvoP. Рабочие параметры (чтение: Modbus...                  NaN
# 4                                                 SP   Уставка регулятора
#
#   Адрес Modbus (hex)    Тип данных Кол-во знаков после запятой  \
# 0                NaN           NaN                         NaN
# 1            0x 0000        binary                           –
# 2            0x 0001  Signed Int16                           *
# 3                NaN           NaN                         NaN
# 4            0x 0002  Signed Int16                           *
#
#   Диапазон значений (dec)
# 0                     NaN
# 1               16 бит 1)
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
df = df[~df["Назначение"].isna()]

# %%
df.head()
# Out:
#   Параметр Имя ОВЕН                            Назначение Адрес Modbus (hex)  \
# 1              STAT                       Регистр статуса            0x 0000
# 2                PV                   Измеренная величина            0x 0001
# 4                SP                    Уставка регулятора            0x 0002
# 5               r-L  Перевод канала на внешнее управление            0x 0003
# 6             r.out                       Выходной сигнал            0x 0004
#
#      Тип данных Кол-во знаков после запятой  \
# 1        binary                           –
# 2  Signed Int16                           *
# 4  Signed Int16                           *
# 5         Int16                         0.0
# 6         Int16                         3.0
#
#                              Диапазон значений (dec)
# 1                                          16 бит 1)
# 2                                                NaN
# 4                                                NaN
# 5                                                0.1
# 6  0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...

# %%
df["Назначение"] = df["Назначение"].apply(lambda s: s.replace("\n", " ").strip())

# %%
df["Назначение"].tail(10)
# Out:
# 27        Тип входного датчика или сигнала
# 28             Точность вывода температуры
# 29              Положение десятичной точки
# 30      Нижняя граница диапазона измерения
# 31     Верхняя граница диапазона измерения
# 32                    Сдвиг характеристики
# 33                   Наклон характеристики
# 34                          Полоса фильтра
# 35    Постоянная времени цифрового фильтра
# 36           Вычислитель квадратного корня
# Name: Назначение, dtype: object

# %%
df["Адрес Modbus (hex)"].head(10)
# Out:
# 1                             0x0000
# 2                             0x0001
# 4                             0x0002
# 5                             0x0003
# 6                             0x0004
# 8     0x1000\n0x1001\n0x1002\n0x1003
# 9     0x1004\n0x1005\n0x1006\n0x1007
# 10                            0x1008
# 11                    0x1009\n0x100A
# 12                    0x100B\n0x100C
# Name: Адрес Modbus (hex), dtype: object

# %%
df["Адрес Modbus (hex)"] = df["Адрес Modbus (hex)"].str.replace(" ", "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_13979/651731380.py in <module>
# ----> 1 df["Адрес Modbus (hex)"] = df["Адрес Modbus (hex)"].str.replace(" ", "").split()
#
# ~/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df["Адрес Modbus (hex)"] = df["Адрес Modbus (hex)"].apply(lambda s: s.split("\n"))

# %%
df.head(10)
# Out:
#    Параметр Имя ОВЕН                            Назначение  \
# 1               STAT                       Регистр статуса
# 2                 PV                   Измеренная величина
# 4                 SP                    Уставка регулятора
# 5                r-L  Перевод канала на внешнее управление
# 6              r.out                       Выходной сигнал
# 8                DEV                           Тип прибора
# 9                VER                        Версия прибора
# 10              STAT                       Регистр статуса
# 11                PV                   Измеренная величина
# 12                SP                    Уставка регулятора
#
#                   Адрес Modbus (hex)    Тип данных  \
# 1                           [0x0000]        binary
# 2                           [0x0001]  Signed Int16
# 4                           [0x0002]  Signed Int16
# 5                           [0x0003]         Int16
# 6                           [0x0004]         Int16
# 8   [0x1000, 0x1001, 0x1002, 0x1003]       Char[8]
# 9   [0x1004, 0x1005, 0x1006, 0x1007]       Char[8]
# 10                          [0x1008]        binary
# 11                  [0x1009, 0x100A]       Float32
# 12                  [0x100B, 0x100C]       Float32
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
#
#                               Диапазон значений (dec)
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN

# %%
df["Адрес Modbus"] = df["Адрес Modbus (hex)"].apply(lambda arr: [eval(addr) for addr in arr])

# %%
columns = df.columns.to_list()

# %%
columns
# Out:
# ['Параметр Имя ОВЕН',
#  'Назначение',
#  'Адрес Modbus (hex)',
#  'Тип данных',
#  'Кол-во знаков после запятой',
#  'Диапазон значений (dec)',
#  'Адрес Modbus']

# %%
col = columns.pop()

# %%
columns.insert(2, col)

# %%
columns
# Out:
# ['Параметр Имя ОВЕН',
#  'Назначение',
#  'Адрес Modbus',
#  'Адрес Modbus (hex)',
#  'Тип данных',
#  'Кол-во знаков после запятой',
#  'Диапазон значений (dec)']

# %%
df = df[columns]

# %%
df
# Out:
#    Параметр Имя ОВЕН                                         Назначение  \
# 1               STAT                                    Регистр статуса
# 2                 PV                                Измеренная величина
# 4                 SP                                 Уставка регулятора
# 5                r-L               Перевод канала на внешнее управление
# 6              r.out                                    Выходной сигнал
# 8                DEV                                        Тип прибора
# 9                VER                                     Версия прибора
# 10              STAT                                    Регистр статуса
# 11                PV                                Измеренная величина
# 12                SP                                 Уставка регулятора
# 14              Prot                                    Протокол обмена
# 15               bPS                                    Скорость обмена
# 16             A.Len                              Длина сетевого адреса
# 17              Addr                              Базовый адрес прибора
# 18              rSdL               Задержка ответа от прибора по RS-485
# 19               Len                                 Длина слова данных
# 20              PrtY                                           Четность
# 21              Sbit                                Количество стоп-бит
# 22             n.Err  Код сетевой ошибки при последнем обращении к п...
# 23              PRTL                     Команда смены протокола обмена
# 24              APLY          Команда смены сетевых значений параметров
# 25              INIT                  Рестарт прибора (аналог выкл\вкл)
# 27              in.t                   Тип входного датчика или сигнала
# 28               dPt                        Точность вывода температуры
# 29                dP                         Положение десятичной точки
# 30              in.L                 Нижняя граница диапазона измерения
# 31              in.H                Верхняя граница диапазона измерения
# 32                SH                               Сдвиг характеристики
# 33                KU                              Наклон характеристики
# 34                Fb                                     Полоса фильтра
# 35               inF               Постоянная времени цифрового фильтра
# 36               Sqr                      Вычислитель квадратного корня
#
#                 Адрес Modbus                Адрес Modbus (hex)    Тип данных  \
# 1                        [0]                          [0x0000]        binary
# 2                        [1]                          [0x0001]  Signed Int16
# 4                        [2]                          [0x0002]  Signed Int16
# 5                        [3]                          [0x0003]         Int16
# 6                        [4]                          [0x0004]         Int16
# 8   [4096, 4097, 4098, 4099]  [0x1000, 0x1001, 0x1002, 0x1003]       Char[8]
# 9   [4100, 4101, 4102, 4103]  [0x1004, 0x1005, 0x1006, 0x1007]       Char[8]
# 10                    [4104]                          [0x1008]        binary
# 11              [4105, 4106]                  [0x1009, 0x100A]       Float32
# 12              [4107, 4108]                  [0x100B, 0x100C]       Float32
# 14                     [256]                          [0x0100]         Int16
# 15                     [257]                          [0x0101]         Int16
# 16                     [258]                          [0x0102]         Int16
# 17                     [259]                          [0x0103]         Int16
# 18                     [260]                          [0x0104]         Int16
# 19                     [261]                          [0x0105]         Int16
# 20                     [262]                          [0x0106]         Int16
# 21                     [263]                          [0x0107]         Int16
# 22                     [264]                          [0x0108]      Hex word
# 23                     [265]                          [0x0109]         Int16
# 24                     [266]                          [0x010A]         Int16
# 25                     [267]                          [0x010B]         Int16
# 27                     [512]                          [0x0200]         Int16
# 28                     [513]                          [0x0201]         Int16
# 29                     [514]                          [0x0202]         Int16
# 30                     [515]                          [0x0203]  Signed Int16
# 31                     [516]                          [0x0204]  Signed Int16
# 32                     [517]                          [0x0205]  Signed Int16
# 33                     [518]                          [0x0206]         Int16
# 34                     [519]                          [0x0207]         Int16
# 35                     [520]                          [0x0208]         Int16
# 36                     [521]                          [0x0209]         Int16
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
# 14                         0.0
# 15                         0.0
# 16                         0.0
# 17                         0.0
# 18                         0.0
# 19                         0.0
# 20                         0.0
# 21                         0.0
# 22                         0.0
# 23                           –
# 24                           –
# 25                           –
# 27                         0.0
# 28                         0.0
# 29                         0.0
# 30                           *
# 31                           *
# 32                           *
# 33                         3.0
# 34                           *
# 35                         0.0
# 36                         0.0
#
#                               Диапазон значений (dec)
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
# 14         – OWEN,\n\n– ModBus-RTU,\n\n– ModBus-ASCII
# 15  [kbps]\n0 – 2.4; 1 – 4.8; 2 – 9.6;\n3 – 14.4; ...
# 16           0 – 8 бит, 1 – 11 бит /\nТолько для ОВЕН
# 17  0… 255 / 0… 2047\nДиапазон указан для протокол...
# 18                                           0… 45 мс
# 19                                 – 7 бит\n\n– 8 бит
# 20                             0 – none (отсутствует)
# 21                       – 1 стоп-бит\n\n– 2 стоп-бит
# 22  Возвращаемые коды ошибок аналогичны протоколу ...
# 23                                                1.0
# 24                                                1.0
# 25                                                1.0
# 27                                              1… 26
# 28                                                0.1
# 29                                            0,1,2,3
# 30                                         -1999…9999
# 31                                         -1999…9999
# 32                                          -500…+500
# 33                                        0.500…2.000
# 34                                             0…9999
# 35                                              0…999
# 36                                  0 – выкл; 1 – вкл

# %%
df["Диапазон значений (dec)"].loc[31].split("…")
# Out:
# ['-1999', '9999']
