# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# patching
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from dissertation_gui.protocols.modbus import TRMModbusDataType

# %%
data_dir = Path(".").resolve().parent.parent / "data"

# %%
data_dir
# Out:
# PosixPath('/home/mfitsek@wooppay.kz/PycharmProjects/dissertation/data')

# %%
df = pd.read_excel(data_dir / "modbus" / "RS-485.xlsx")

# %%
df
# Out:
#                                     Параметр Имя ОВЕН  \
# 0   Группа LvoP. Оперативные параметры (только чте...
# 1                                                STAT
# 2                                                  PV
# 3   Группа LvoP. Рабочие параметры (чтение: Modbus...
# 4                                                  SP
# 5                                                 r-L
# 6                                               r.out
# 7   Группа LvoP. Оперативные параметры (только чте...
# 8                                                 DEV
# 9                                                 VER
# 10                                               STAT
# 11                                                 PV
# 12                                                 SP
# 13  Группа Comm. Параметра обмена (чтение: Modbus-...
# 14                                               Prot
# 15                                                bPS
# 16                                              A.Len
# 17                                               Addr
# 18                                               rSdL
# 19                                                Len
# 20                                               PrtY
# 21                                               Sbit
# 22                                              n.Err
# 23                                               PRTL
# 24                                               APLY
# 25                                               INIT
# 26  Группа Lvin. Параметры входов (чтение: Modbus-...
# 27                                               in.t
# 28                                                dPt
# 29                                                 dP
# 30                                               in.L
# 31                                               in.H
# 32                                                 SH
# 33                                                 KU
# 34                                                 Fb
# 35                                                inF
# 36                                                Sqr
# 37  Группа Adv. Параметры индикации (чтение: Modbu...
# 38                                               rESt
# 39  Группа LvoU.Настройки регулирования и регистра...
# 40                                               SL.L
# 41                                               SL.H
# 42                                                CmP
# 43                                                HYS
# 44                                                don
# 45                                                doF
# 46                                                ton
# 47                                                toF
# 48                                                oEr
# 49                                                dAC
# 50                                               An.L
# 51                                               An.H
# 52                                                CtL
# 53                                                 XP
# 54  Группа SECr. Параметры секретности (чтение: Mo...
# 55                                               oAPt
# 56                                               wtPt
# 57                                               EdPt
#
#                                            Назначение  \
# 0                                                 NaN
# 1                                     Регистр статуса
# 2                                 Измеренная величина
# 3                                                 NaN
# 4                                  Уставка регулятора
# 5                Перевод канала на внешнее управление
# 6                                     Выходной сигнал
# 7                                                 NaN
# 8                                         Тип прибора
# 9                                      Версия прибора
# 10                                    Регистр статуса
# 11                                Измеренная величина
# 12                                 Уставка регулятора
# 13                                                NaN
# 14                                    Протокол обмена
# 15                                    Скорость обмена
# 16                              Длина сетевого адреса
# 17                              Базовый адрес прибора
# 18              Задержка ответа от прибора по\nRS-485
# 19                                 Длина слова данных
# 20                                           Четность
# 21                                Количество стоп-бит
# 22  Код сетевой ошибки при последнем обращении к п...
# 23                     Команда смены протокола обмена
# 24          Команда смены сетевых значений параметров
# 25                 Рестарт прибора\n(аналог выкл\вкл)
# 26                                                NaN
# 27                   Тип входного датчика или сигнала
# 28                        Точность вывода температуры
# 29                         Положение десятичной точки
# 30                 Нижняя граница диапазона измерения
# 31                Верхняя граница диапазона измерения
# 32                               Сдвиг характеристики
# 33                              Наклон характеристики
# 34                                     Полоса фильтра
# 35               Постоянная времени цифрового фильтра
# 36                      Вычислитель квадратного корня
# 37                                                NaN
# 38            Время выхода из режима программирования
# 39                                                NaN
# 40                     Нижняя граница задания уставки
# 41                    Верхняя граница задания уставки
# 42                             Тип логики компаратора
# 43                         Гистерезис для компаратора
# 44                     Задержка включения компаратора
# 45                    Задержка выключения компаратора
# 46  Минимальное время удерживания компаратора во в...
# 47  Минимальное время удерживания компаратора в вы...
# 48                Состояние выхода в режиме\n«ошибка»
# 49                                   Режим работы ЦАП
# 50  Нижняя граница выходного диапазона регистрации...
# 51  Верхняя граница выходного диапазона регистраци...
# 52                       Способ управления для выхода
# 53               Полоса пропорциональности для выхода
# 54                                                NaN
# 55                     Защита параметров от просмотра
# 56                     Защита параметров от изменения
# 57  Защита отдельных параметров от просмотра и изм...
#
#                     Адрес Modbus (hex)    Тип данных  \
# 0                                  NaN           NaN
# 1                              0x 0000        binary
# 2                              0x 0001  Signed Int16
# 3                                  NaN           NaN
# 4                              0x 0002  Signed Int16
# 5                              0x 0003         Int16
# 6                              0x 0004         Int16
# 7                                  NaN           NaN
# 8   0x 1000\n0x 1001\n0x 1002\n0x 1003       Char[8]
# 9   0x 1004\n0x 1005\n0x 1006\n0x 1007       Char[8]
# 10                             0x 1008        binary
# 11                    0x 1009\n0x 100A       Float32
# 12                      0x100B\n0x100C       Float32
# 13                                 NaN           NaN
# 14                             0x 0100         Int16
# 15                              0x0101         Int16
# 16                              0x0102         Int16
# 17                              0x0103         Int16
# 18                              0x0104         Int16
# 19                              0x0105         Int16
# 20                              0x0106         Int16
# 21                              0x0107         Int16
# 22                              0x0108      Hex word
# 23                              0x0109         Int16
# 24                              0x010A         Int16
# 25                              0x010B         Int16
# 26                                 NaN           NaN
# 27                             0x 0200         Int16
# 28                             0x 0201         Int16
# 29                             0x 0202         Int16
# 30                             0x 0203  Signed Int16
# 31                             0x 0204  Signed Int16
# 32                             0x 0205  Signed Int16
# 33                             0x 0206         Int16
# 34                             0x 0207         Int16
# 35                             0x 0208         Int16
# 36                             0x 0209         Int16
# 37                                 NaN           NaN
# 38                             0x 0300         Int16
# 39                                 NaN           NaN
# 40                             0x 0400  Signed Int16
# 41                             0x 0401  Signed Int16
# 42                             0x 0402         Int16
# 43                             0x 0403         Int16
# 44                             0x 0404         Int16
# 45                             0x 0405         Int16
# 46                             0x 0406         Int16
# 47                             0x 0407         Int16
# 48                             0x 0408         Int16
# 49                             0x 0409         Int16
# 50                             0x 040A  Signed Int16
# 51                             0x 040B  Signed Int16
# 52                             0x 040C         Int16
# 53                             0x 040D         Int16
# 54                                 NaN           NaN
# 55                             0x 0700         Int16
# 56                             0x 0701         Int16
# 57                             0x 0702         Int16
#
#    Кол-во знаков после запятой  \
# 0                          NaN
# 1                            –
# 2                            *
# 3                          NaN
# 4                            *
# 5                          0.0
# 6                          3.0
# 7                          NaN
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
# 13                         NaN
# 14                         0.0
# 15                         0.0
# 16                         0.0
# 17                         0.0
# 18                         0.0
# 19                         0.0
# 20                         0.0
# 21                         0.0
# 22                         0.0
# 23                           –
# 24                           –
# 25                           –
# 26                         NaN
# 27                         0.0
# 28                         0.0
# 29                         0.0
# 30                           *
# 31                           *
# 32                           *
# 33                         3.0
# 34                           *
# 35                         0.0
# 36                         0.0
# 37                         NaN
# 38                         0.0
# 39                         NaN
# 40                           *
# 41                           *
# 42                         0.0
# 43                           *
# 44                         0.0
# 45                         0.0
# 46                         0.0
# 47                         0.0
# 48                         0.0
# 49                         0.0
# 50                           *
# 51                           *
# 52                         0.0
# 53                           *
# 54                         NaN
# 55                         0.0
# 56                         0.0
# 57                         0.0
#
#                               Диапазон значений (dec)
# 0                                                 NaN
# 1                                           16 бит 1)
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 7                                                 NaN
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14         – OWEN,\n\n– ModBus-RTU,\n\n– ModBus-ASCII
# 15  [kbps]\n0 – 2.4; 1 – 4.8; 2 – 9.6;\n3 – 14.4; ...
# 16           0 – 8 бит, 1 – 11 бит /\nТолько для ОВЕН
# 17  0… 255 / 0… 2047\nДиапазон указан для протокол...
# 18                                           0… 45 мс
# 19                                 – 7 бит\n\n– 8 бит
# 20                             0 – none (отсутствует)
# 21                       – 1 стоп-бит\n\n– 2 стоп-бит
# 22  Возвращаемые коды ошибок аналогичны протоколу ...
# 23                                                1.0
# 24                                                1.0
# 25                                                1.0
# 26                                                NaN
# 27                                              1… 26
# 28                                                0.1
# 29                                            0,1,2,3
# 30                                         -1999…9999
# 31                                         -1999…9999
# 32                                          -500…+500
# 33                                        0.500…2.000
# 34                                             0…9999
# 35                                              0…999
# 36                                  0 – выкл; 1 – вкл
# 37                                                NaN
# 38                                              5…100
# 39                                                NaN
# 40                              диапазон изм. датчика
# 41                              диапазон изм. датчика
# 42  – выкл;\n\n– нагреватель;\n\n– холодильник;\n\...
# 43                                             0…9999
# 44                                            0 … 250
# 45                                            0 … 250
# 46                                            0 … 250
# 47                                            0 … 250
# 48                                  0 – выкл; 1 – вкл
# 49                    – регистратор;\n\n– П-регулятор
# 50                              диапазон изм. датчика
# 51                              диапазон изм. датчика
# 52                     – нагреватель\n\n– холодильник
# 53                                             2…9999
# 54                                                NaN
# 55                                               0… 2
# 56                                               0… 2
# 57                                  0 – выкл; 1 – вкл

# %%
df = df[~df["Назначение"].isna()]

# %%
df.head()
# Out:
#   Параметр Имя ОВЕН                            Назначение Адрес Modbus (hex)  \
# 1              STAT                       Регистр статуса            0x 0000
# 2                PV                   Измеренная величина            0x 0001
# 4                SP                    Уставка регулятора            0x 0002
# 5               r-L  Перевод канала на внешнее управление            0x 0003
# 6             r.out                       Выходной сигнал            0x 0004
#
#      Тип данных Кол-во знаков после запятой  \
# 1        binary                           –
# 2  Signed Int16                           *
# 4  Signed Int16                           *
# 5         Int16                         0.0
# 6         Int16                         3.0
#
#                              Диапазон значений (dec)
# 1                                          16 бит 1)
# 2                                                NaN
# 4                                                NaN
# 5                                                0.1
# 6  0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...

# %%
df["Назначение"] = df["Назначение"].apply(lambda s: s.replace("\n", " ").strip())
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Назначение"].tail(10)
# Out:
# 47    Минимальное время удерживания компаратора в вы...
# 48                   Состояние выхода в режиме «ошибка»
# 49                                     Режим работы ЦАП
# 50    Нижняя граница выходного диапазона регистрации...
# 51    Верхняя граница выходного диапазона регистраци...
# 52                         Способ управления для выхода
# 53                 Полоса пропорциональности для выхода
# 55                       Защита параметров от просмотра
# 56                       Защита параметров от изменения
# 57    Защита отдельных параметров от просмотра и изм...
# Name: Назначение, dtype: object

# %%
df["Адрес Modbus (hex)"].head(10)
# Out:
# 1                                0x 0000
# 2                                0x 0001
# 4                                0x 0002
# 5                                0x 0003
# 6                                0x 0004
# 8     0x 1000\n0x 1001\n0x 1002\n0x 1003
# 9     0x 1004\n0x 1005\n0x 1006\n0x 1007
# 10                               0x 1008
# 11                      0x 1009\n0x 100A
# 12                        0x100B\n0x100C
# Name: Адрес Modbus (hex), dtype: object

# %%
df["Адрес Modbus (hex)"] = df["Адрес Modbus (hex)"].str.replace(" ", "")
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Адрес Modbus (hex)"] = df["Адрес Modbus (hex)"].apply(lambda s: s.split("\n"))
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#    Параметр Имя ОВЕН                            Назначение  \
# 1               STAT                       Регистр статуса
# 2                 PV                   Измеренная величина
# 4                 SP                    Уставка регулятора
# 5                r-L  Перевод канала на внешнее управление
# 6              r.out                       Выходной сигнал
# 8                DEV                           Тип прибора
# 9                VER                        Версия прибора
# 10              STAT                       Регистр статуса
# 11                PV                   Измеренная величина
# 12                SP                    Уставка регулятора
#
#                   Адрес Modbus (hex)    Тип данных  \
# 1                           [0x0000]        binary
# 2                           [0x0001]  Signed Int16
# 4                           [0x0002]  Signed Int16
# 5                           [0x0003]         Int16
# 6                           [0x0004]         Int16
# 8   [0x1000, 0x1001, 0x1002, 0x1003]       Char[8]
# 9   [0x1004, 0x1005, 0x1006, 0x1007]       Char[8]
# 10                          [0x1008]        binary
# 11                  [0x1009, 0x100A]       Float32
# 12                  [0x100B, 0x100C]       Float32
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
#
#                               Диапазон значений (dec)
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN

# %%
df["Адрес Modbus"] = df["Адрес Modbus (hex)"].apply(lambda arr: [eval(addr) for addr in arr])
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#    Параметр Имя ОВЕН                            Назначение  \
# 1               STAT                       Регистр статуса
# 2                 PV                   Измеренная величина
# 4                 SP                    Уставка регулятора
# 5                r-L  Перевод канала на внешнее управление
# 6              r.out                       Выходной сигнал
# 8                DEV                           Тип прибора
# 9                VER                        Версия прибора
# 10              STAT                       Регистр статуса
# 11                PV                   Измеренная величина
# 12                SP                    Уставка регулятора
#
#                   Адрес Modbus (hex)    Тип данных  \
# 1                           [0x0000]        binary
# 2                           [0x0001]  Signed Int16
# 4                           [0x0002]  Signed Int16
# 5                           [0x0003]         Int16
# 6                           [0x0004]         Int16
# 8   [0x1000, 0x1001, 0x1002, 0x1003]       Char[8]
# 9   [0x1004, 0x1005, 0x1006, 0x1007]       Char[8]
# 10                          [0x1008]        binary
# 11                  [0x1009, 0x100A]       Float32
# 12                  [0x100B, 0x100C]       Float32
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
#
#                               Диапазон значений (dec)  \
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
#
#                 Адрес Modbus
# 1                        [0]
# 2                        [1]
# 4                        [2]
# 5                        [3]
# 6                        [4]
# 8   [4096, 4097, 4098, 4099]
# 9   [4100, 4101, 4102, 4103]
# 10                    [4104]
# 11              [4105, 4106]
# 12              [4107, 4108]

# %%
df["Количество регистров"] = df["Адрес Modbus"].apply(lambda x: len(x))
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#    Параметр Имя ОВЕН                            Назначение  \
# 1               STAT                       Регистр статуса
# 2                 PV                   Измеренная величина
# 4                 SP                    Уставка регулятора
# 5                r-L  Перевод канала на внешнее управление
# 6              r.out                       Выходной сигнал
# 8                DEV                           Тип прибора
# 9                VER                        Версия прибора
# 10              STAT                       Регистр статуса
# 11                PV                   Измеренная величина
# 12                SP                    Уставка регулятора
#
#                   Адрес Modbus (hex)    Тип данных  \
# 1                           [0x0000]        binary
# 2                           [0x0001]  Signed Int16
# 4                           [0x0002]  Signed Int16
# 5                           [0x0003]         Int16
# 6                           [0x0004]         Int16
# 8   [0x1000, 0x1001, 0x1002, 0x1003]       Char[8]
# 9   [0x1004, 0x1005, 0x1006, 0x1007]       Char[8]
# 10                          [0x1008]        binary
# 11                  [0x1009, 0x100A]       Float32
# 12                  [0x100B, 0x100C]       Float32
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
#
#                               Диапазон значений (dec)  \
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
#
#                 Адрес Modbus  Количество регистров
# 1                        [0]                     1
# 2                        [1]                     1
# 4                        [2]                     1
# 5                        [3]                     1
# 6                        [4]                     1
# 8   [4096, 4097, 4098, 4099]                     4
# 9   [4100, 4101, 4102, 4103]                     4
# 10                    [4104]                     1
# 11              [4105, 4106]                     2
# 12              [4107, 4108]                     2

# %%
df["Тип данных"] = df["Тип данных"].apply(lambda x: TRMModbusDataType(x))
# Out:
# /home/mfitsek@wooppay.kz/PycharmProjects/dissertation/venv/lib64/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#    Параметр Имя ОВЕН                            Назначение  \
# 1               STAT                       Регистр статуса
# 2                 PV                   Измеренная величина
# 4                 SP                    Уставка регулятора
# 5                r-L  Перевод канала на внешнее управление
# 6              r.out                       Выходной сигнал
# 8                DEV                           Тип прибора
# 9                VER                        Версия прибора
# 10              STAT                       Регистр статуса
# 11                PV                   Измеренная величина
# 12                SP                    Уставка регулятора
#
#                   Адрес Modbus (hex)                       Тип данных  \
# 1                           [0x0000]         TRMModbusDataType.BINARY
# 2                           [0x0001]  TRMModbusDataType.SIGNED_INT_16
# 4                           [0x0002]  TRMModbusDataType.SIGNED_INT_16
# 5                           [0x0003]         TRMModbusDataType.INT_16
# 6                           [0x0004]         TRMModbusDataType.INT_16
# 8   [0x1000, 0x1001, 0x1002, 0x1003]         TRMModbusDataType.CHAR_8
# 9   [0x1004, 0x1005, 0x1006, 0x1007]         TRMModbusDataType.CHAR_8
# 10                          [0x1008]         TRMModbusDataType.BINARY
# 11                  [0x1009, 0x100A]       TRMModbusDataType.FLOAT_32
# 12                  [0x100B, 0x100C]       TRMModbusDataType.FLOAT_32
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
#
#                               Диапазон значений (dec)  \
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
#
#                 Адрес Modbus  Количество регистров
# 1                        [0]                     1
# 2                        [1]                     1
# 4                        [2]                     1
# 5                        [3]                     1
# 6                        [4]                     1
# 8   [4096, 4097, 4098, 4099]                     4
# 9   [4100, 4101, 4102, 4103]                     4
# 10                    [4104]                     1
# 11              [4105, 4106]                     2
# 12              [4107, 4108]                     2

# %%
columns = df.columns.to_list()

# %%
columns
# Out:
# ['Параметр Имя ОВЕН',
#  'Назначение',
#  'Адрес Modbus (hex)',
#  'Тип данных',
#  'Кол-во знаков после запятой',
#  'Диапазон значений (dec)',
#  'Адрес Modbus',
#  'Количество регистров']

# %%
columns = columns[:3] + columns[-2:] + columns[3:-2]

# %%
columns = columns[:2] + columns[5:6] + columns[2:5] + columns[6:]

# %%
columns
# Out:
# ['Параметр Имя ОВЕН',
#  'Назначение',
#  'Тип данных',
#  'Адрес Modbus (hex)',
#  'Адрес Modbus',
#  'Количество регистров',
#  'Кол-во знаков после запятой',
#  'Диапазон значений (dec)']

# %%
df = df[columns]

# %%
df
# Out:
#    Параметр Имя ОВЕН                                         Назначение  \
# 1               STAT                                    Регистр статуса
# 2                 PV                                Измеренная величина
# 4                 SP                                 Уставка регулятора
# 5                r-L               Перевод канала на внешнее управление
# 6              r.out                                    Выходной сигнал
# 8                DEV                                        Тип прибора
# 9                VER                                     Версия прибора
# 10              STAT                                    Регистр статуса
# 11                PV                                Измеренная величина
# 12                SP                                 Уставка регулятора
# 14              Prot                                    Протокол обмена
# 15               bPS                                    Скорость обмена
# 16             A.Len                              Длина сетевого адреса
# 17              Addr                              Базовый адрес прибора
# 18              rSdL               Задержка ответа от прибора по RS-485
# 19               Len                                 Длина слова данных
# 20              PrtY                                           Четность
# 21              Sbit                                Количество стоп-бит
# 22             n.Err  Код сетевой ошибки при последнем обращении к п...
# 23              PRTL                     Команда смены протокола обмена
# 24              APLY          Команда смены сетевых значений параметров
# 25              INIT                  Рестарт прибора (аналог выкл\вкл)
# 27              in.t                   Тип входного датчика или сигнала
# 28               dPt                        Точность вывода температуры
# 29                dP                         Положение десятичной точки
# 30              in.L                 Нижняя граница диапазона измерения
# 31              in.H                Верхняя граница диапазона измерения
# 32                SH                               Сдвиг характеристики
# 33                KU                              Наклон характеристики
# 34                Fb                                     Полоса фильтра
# 35               inF               Постоянная времени цифрового фильтра
# 36               Sqr                      Вычислитель квадратного корня
# 38              rESt            Время выхода из режима программирования
# 40              SL.L                     Нижняя граница задания уставки
# 41              SL.H                    Верхняя граница задания уставки
# 42               CmP                             Тип логики компаратора
# 43               HYS                         Гистерезис для компаратора
# 44               don                     Задержка включения компаратора
# 45               doF                    Задержка выключения компаратора
# 46               ton  Минимальное время удерживания компаратора во в...
# 47               toF  Минимальное время удерживания компаратора в вы...
# 48               oEr                 Состояние выхода в режиме «ошибка»
# 49               dAC                                   Режим работы ЦАП
# 50              An.L  Нижняя граница выходного диапазона регистрации...
# 51              An.H  Верхняя граница выходного диапазона регистраци...
# 52               CtL                       Способ управления для выхода
# 53                XP               Полоса пропорциональности для выхода
# 55              oAPt                     Защита параметров от просмотра
# 56              wtPt                     Защита параметров от изменения
# 57              EdPt  Защита отдельных параметров от просмотра и изм...
#
#                          Тип данных                Адрес Modbus (hex)  \
# 1          TRMModbusDataType.BINARY                          [0x0000]
# 2   TRMModbusDataType.SIGNED_INT_16                          [0x0001]
# 4   TRMModbusDataType.SIGNED_INT_16                          [0x0002]
# 5          TRMModbusDataType.INT_16                          [0x0003]
# 6          TRMModbusDataType.INT_16                          [0x0004]
# 8          TRMModbusDataType.CHAR_8  [0x1000, 0x1001, 0x1002, 0x1003]
# 9          TRMModbusDataType.CHAR_8  [0x1004, 0x1005, 0x1006, 0x1007]
# 10         TRMModbusDataType.BINARY                          [0x1008]
# 11       TRMModbusDataType.FLOAT_32                  [0x1009, 0x100A]
# 12       TRMModbusDataType.FLOAT_32                  [0x100B, 0x100C]
# 14         TRMModbusDataType.INT_16                          [0x0100]
# 15         TRMModbusDataType.INT_16                          [0x0101]
# 16         TRMModbusDataType.INT_16                          [0x0102]
# 17         TRMModbusDataType.INT_16                          [0x0103]
# 18         TRMModbusDataType.INT_16                          [0x0104]
# 19         TRMModbusDataType.INT_16                          [0x0105]
# 20         TRMModbusDataType.INT_16                          [0x0106]
# 21         TRMModbusDataType.INT_16                          [0x0107]
# 22       TRMModbusDataType.HEX_WORD                          [0x0108]
# 23         TRMModbusDataType.INT_16                          [0x0109]
# 24         TRMModbusDataType.INT_16                          [0x010A]
# 25         TRMModbusDataType.INT_16                          [0x010B]
# 27         TRMModbusDataType.INT_16                          [0x0200]
# 28         TRMModbusDataType.INT_16                          [0x0201]
# 29         TRMModbusDataType.INT_16                          [0x0202]
# 30  TRMModbusDataType.SIGNED_INT_16                          [0x0203]
# 31  TRMModbusDataType.SIGNED_INT_16                          [0x0204]
# 32  TRMModbusDataType.SIGNED_INT_16                          [0x0205]
# 33         TRMModbusDataType.INT_16                          [0x0206]
# 34         TRMModbusDataType.INT_16                          [0x0207]
# 35         TRMModbusDataType.INT_16                          [0x0208]
# 36         TRMModbusDataType.INT_16                          [0x0209]
# 38         TRMModbusDataType.INT_16                          [0x0300]
# 40  TRMModbusDataType.SIGNED_INT_16                          [0x0400]
# 41  TRMModbusDataType.SIGNED_INT_16                          [0x0401]
# 42         TRMModbusDataType.INT_16                          [0x0402]
# 43         TRMModbusDataType.INT_16                          [0x0403]
# 44         TRMModbusDataType.INT_16                          [0x0404]
# 45         TRMModbusDataType.INT_16                          [0x0405]
# 46         TRMModbusDataType.INT_16                          [0x0406]
# 47         TRMModbusDataType.INT_16                          [0x0407]
# 48         TRMModbusDataType.INT_16                          [0x0408]
# 49         TRMModbusDataType.INT_16                          [0x0409]
# 50  TRMModbusDataType.SIGNED_INT_16                          [0x040A]
# 51  TRMModbusDataType.SIGNED_INT_16                          [0x040B]
# 52         TRMModbusDataType.INT_16                          [0x040C]
# 53         TRMModbusDataType.INT_16                          [0x040D]
# 55         TRMModbusDataType.INT_16                          [0x0700]
# 56         TRMModbusDataType.INT_16                          [0x0701]
# 57         TRMModbusDataType.INT_16                          [0x0702]
#
#                 Адрес Modbus  Количество регистров  \
# 1                        [0]                     1
# 2                        [1]                     1
# 4                        [2]                     1
# 5                        [3]                     1
# 6                        [4]                     1
# 8   [4096, 4097, 4098, 4099]                     4
# 9   [4100, 4101, 4102, 4103]                     4
# 10                    [4104]                     1
# 11              [4105, 4106]                     2
# 12              [4107, 4108]                     2
# 14                     [256]                     1
# 15                     [257]                     1
# 16                     [258]                     1
# 17                     [259]                     1
# 18                     [260]                     1
# 19                     [261]                     1
# 20                     [262]                     1
# 21                     [263]                     1
# 22                     [264]                     1
# 23                     [265]                     1
# 24                     [266]                     1
# 25                     [267]                     1
# 27                     [512]                     1
# 28                     [513]                     1
# 29                     [514]                     1
# 30                     [515]                     1
# 31                     [516]                     1
# 32                     [517]                     1
# 33                     [518]                     1
# 34                     [519]                     1
# 35                     [520]                     1
# 36                     [521]                     1
# 38                     [768]                     1
# 40                    [1024]                     1
# 41                    [1025]                     1
# 42                    [1026]                     1
# 43                    [1027]                     1
# 44                    [1028]                     1
# 45                    [1029]                     1
# 46                    [1030]                     1
# 47                    [1031]                     1
# 48                    [1032]                     1
# 49                    [1033]                     1
# 50                    [1034]                     1
# 51                    [1035]                     1
# 52                    [1036]                     1
# 53                    [1037]                     1
# 55                    [1792]                     1
# 56                    [1793]                     1
# 57                    [1794]                     1
#
#    Кол-во знаков после запятой  \
# 1                            –
# 2                            *
# 4                            *
# 5                          0.0
# 6                          3.0
# 8                            –
# 9                            –
# 10                           –
# 11                           –
# 12                           –
# 14                         0.0
# 15                         0.0
# 16                         0.0
# 17                         0.0
# 18                         0.0
# 19                         0.0
# 20                         0.0
# 21                         0.0
# 22                         0.0
# 23                           –
# 24                           –
# 25                           –
# 27                         0.0
# 28                         0.0
# 29                         0.0
# 30                           *
# 31                           *
# 32                           *
# 33                         3.0
# 34                           *
# 35                         0.0
# 36                         0.0
# 38                         0.0
# 40                           *
# 41                           *
# 42                         0.0
# 43                           *
# 44                         0.0
# 45                         0.0
# 46                         0.0
# 47                         0.0
# 48                         0.0
# 49                         0.0
# 50                           *
# 51                           *
# 52                         0.0
# 53                           *
# 55                         0.0
# 56                         0.0
# 57                         0.0
#
#                               Диапазон значений (dec)
# 1                                           16 бит 1)
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 0.1
# 6   0,1 (ВУ ключевого типа) 0.000 … 1.000\n(ВУ ана...
# 8                                              ТРМ201
# 9                                            V03.00xx
# 10                                          16 бит 1)
# 11                                                NaN
# 12                                                NaN
# 14         – OWEN,\n\n– ModBus-RTU,\n\n– ModBus-ASCII
# 15  [kbps]\n0 – 2.4; 1 – 4.8; 2 – 9.6;\n3 – 14.4; ...
# 16           0 – 8 бит, 1 – 11 бит /\nТолько для ОВЕН
# 17  0… 255 / 0… 2047\nДиапазон указан для протокол...
# 18                                           0… 45 мс
# 19                                 – 7 бит\n\n– 8 бит
# 20                             0 – none (отсутствует)
# 21                       – 1 стоп-бит\n\n– 2 стоп-бит
# 22  Возвращаемые коды ошибок аналогичны протоколу ...
# 23                                                1.0
# 24                                                1.0
# 25                                                1.0
# 27                                              1… 26
# 28                                                0.1
# 29                                            0,1,2,3
# 30                                         -1999…9999
# 31                                         -1999…9999
# 32                                          -500…+500
# 33                                        0.500…2.000
# 34                                             0…9999
# 35                                              0…999
# 36                                  0 – выкл; 1 – вкл
# 38                                              5…100
# 40                              диапазон изм. датчика
# 41                              диапазон изм. датчика
# 42  – выкл;\n\n– нагреватель;\n\n– холодильник;\n\...
# 43                                             0…9999
# 44                                            0 … 250
# 45                                            0 … 250
# 46                                            0 … 250
# 47                                            0 … 250
# 48                                  0 – выкл; 1 – вкл
# 49                    – регистратор;\n\n– П-регулятор
# 50                              диапазон изм. датчика
# 51                              диапазон изм. датчика
# 52                     – нагреватель\n\n– холодильник
# 53                                             2…9999
# 55                                               0… 2
# 56                                               0… 2
# 57                                  0 – выкл; 1 – вкл

# %%
df["Диапазон значений (dec)"].loc[42]
# Out:
# '– выкл;\n\n– нагреватель;\n\n– холодильник;\n\n– П-образная,\n\n– U-образная'
